-- %%
%python
from pipeline.postgres import get_connection_config, read_table

jdbc_url, properties = get_connection_config(dbutils)

orders_df = read_table(
    spark,
    "orders",
    jdbc_url,
    properties
)

orders_df.show(5)
